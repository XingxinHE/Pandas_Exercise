# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df = df.loc[:,'school':'guardian']
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
def format(x):
  return x.str.capitalize()

# %%
#lambda function是这样的
#capitalizer = lambda x: x.capitalize()
#df['Mjob'].apply(capitalizer)
#df['Fjob'].apply(capitalizer)

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df[['Mjob', 'Fjob']] = df[['Mjob', 'Fjob']].apply(format)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail(1)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  \
# 394     MS   M   19       U     LE3       T     1     1  Other  At_home
#
#      reason guardian
# 394  course   father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df.head() #明显已经cap了
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(dataframe):
  dataframe['legal_drinker'] = dataframe['age'] > 17

# %%
majority(df)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other
# 3     GP   F   15       U     GT3       T     4     2   Health  Services
# 4     GP   F   16       U     GT3       T     3     3    Other     Other
#
#    reason guardian  legal_drinker
# 0  course   mother           True
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %% [markdown]
# 我做的时候很疑惑为啥不直接弄呢还要写个function，才发现它的function不是我那种级别的……

# %%
# def majority(x):
#   if x > 17:
#     return True
#   else:
#     return False

# %%
# df['legal_drinker'] = df['age'].apply(majority)
# 这才是这道题的原意思

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df * 10
# Out:
#                    school         sex  age     address  \
# 0    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  180  UUUUUUUUUU
# 1    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  170  UUUUUUUUUU
# 2    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 3    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 4    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 5    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 6    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 7    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  170  UUUUUUUUUU
# 8    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 9    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 10   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 11   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 12   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 13   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 14   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 15   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# ...

# %%
#做个筛选的 * 10
def multiply_ten(x):
  if type(x) is int:
    return x * 10
  else:
    return x

# %%
df.applymap(multiply_ten) #你就可以看到age被×了10
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F  180       U     GT3       A    40    40   At_home   Teacher
# 1       GP   F  170       U     GT3       T    10    10   At_home     Other
# 2       GP   F  150       U     LE3       T    10    10   At_home     Other
# 3       GP   F  150       U     GT3       T    40    20    Health  Services
# 4       GP   F  160       U     GT3       T    30    30     Other     Other
# 5       GP   M  160       U     LE3       T    40    30  Services     Other
# 6       GP   M  160       U     LE3       T    20    20     Other     Other
# 7       GP   F  170       U     GT3       A    40    40     Other   Teacher
# 8       GP   M  150       U     LE3       A    30    20  Services     Other
# 9       GP   M  150       U     GT3       T    30    40     Other     Other
# 10      GP   F  150       U     GT3       T    40    40   Teacher    Health
# ...
